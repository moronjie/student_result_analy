# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./study_performance.csv')
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
ax = sns.countplot(data=df, x='gender', hue='gender')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.show()

# %%
ple = df.groupby('parental_level_of_education').agg({'math_score': 'mean', 'reading_score': 'mean', 'writing_score': 'mean'})
print(ple)

sns.heatmap(ple, annot=True, cmap="coolwarm")
plt.title('how parent level of education affects student performance')
plt.show()
# Out:
#                              math_score  reading_score  writing_score
# parental_level_of_education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
re = df.groupby('race_ethnicity').agg({'math_score': 'mean', 'reading_score': 'mean', 'writing_score': 'mean'})
print(ple)

sns.heatmap(re, annot=True, cmap="coolwarm")
plt.title('how race ethnicity affects student performance')
plt.show()
# Out:
#                              math_score  reading_score  writing_score
# parental_level_of_education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
sns.boxenplot(data=df, x='math_score')
plt.show()

# %%
sns.boxenplot(data=df, x='reading_score')
plt.show()

# %%
sns.boxenplot(data=df, x='writing_score')
plt.show()

# %%
df['race_ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
groupA = df.loc[df['race_ethnicity'] == 'group A'].count()
groupB = df.loc[df['race_ethnicity'] == 'group B'].count()
groupC = df.loc[df['race_ethnicity'] == 'group C'].count()
groupD = df.loc[df['race_ethnicity'] == 'group D'].count()
groupE = df.loc[df['race_ethnicity'] == 'group E'].count()

# %%
grp = [groupA['race_ethnicity'], groupB['race_ethnicity'], groupC['race_ethnicity'], groupD['race_ethnicity'], groupE['race_ethnicity']]
grp_label = ['Group A', 'Group B', 'Group C', 'Group D', 'Group E']
print(grp)
# Out:
# [89, 190, 319, 262, 140]

# %%
plt.pie(grp, autopct='%1.1f%%', labels=grp_label)
plt.show()

# %%
sns.countplot(df, x="race_ethnicity", hue="race_ethnicity")
# Out:
# <Axes: xlabel='race_ethnicity', ylabel='count'>
